# %%
# !pip uninstall httpx httpcore
# !pip install --upgrade httpx httpcore

# %%
import numpy as np
import pandas as pd
import os
from openai import OpenAI
import math
import json
import re
import builtins
import csv
from deep_translator import GoogleTranslator

# %%
with open('config.json') as config_file:
    config = json.load(config_file)
    open_api_key = config['open_api_key']
client = OpenAI(api_key=open_api_key)

# %%
selected_files = ['100-200.csv', '0-100.csv', '200-300.csv', '300-400.csv', '700-800.csv', '900-1000.csv', '500-600.csv', '400-500.csv', '600-700.csv', '800-900.csv']
# selected_files += ['1000-1250.csv', '1250-1500.csv','1500-1750.csv',
# '1750-2000.csv']
selected_files += ['2000-2250.csv','2250-2500.csv',
'2500-2750.csv',
'2750-3000.csv']
selected_files += ['3000-3250.csv', '3250-3500.csv']#,'3500-3750.csv','3750-4000.csv']

# %%
language = 'Spanish'
language_code = 'es'

# %%
def get_sets_to_do(post_directory):
    os.makedirs(os.path.join(language, 'Vocabulary', post_directory), exist_ok = True)
    donesets = os.listdir(os.path.join(language, 'Vocabulary', post_directory))
    print('Done:', donesets)
    if '.DS_Store' in donesets:
        donesets.remove('.DS_Store')
    allsets = os.listdir(os.path.join(language, 'Vocabulary', 'split_sets'))
    notdonesets = [i for i in allsets if not i in donesets]
    todosets = notdonesets#['900-1000.csv']
    if '.DS_Store' in donesets:
        todosets.remove('.DS_Store')
    print('To Do:', todosets)
    return todosets
# todosets = get_sets_to_do('Split_Sets','ChatGPT_Sets')

# %%
frequencydf = pd.read_csv(os.path.join('Frequency Lists', language, 'Clean.csv'))
# frequencydf

# %% [markdown]
# Clean

# %% [markdown]
# VOCABULARY SPLIT

# %%
import os
import math

def split_into_studysets(frequencydf, language, initial_splitsize=100, new_splitsize=250):
    os.makedirs(os.path.join(language, 'Vocabulary', 'Split_Sets'), exist_ok=True)
    columns = [language]
    if 'POS' in frequencydf.columns:
        columns.append('POS')
    if 'Translation' in frequencydf.columns:
        columns.append('Translation')
    if 'English' in frequencydf.columns:
        frequencydf.rename(columns={'English': 'Translation'}, inplace=True)
        columns.append('Translation')
    if 'lemma' in frequencydf.columns:
        columns.append('show')
        columns.append('lemma')
    print('columns:', columns)
    
    total_rows = len(frequencydf)
    i = 0
    splitsize = initial_splitsize
    
    while i * splitsize < total_rows:
        if i * splitsize >= 1000:
            splitsize = new_splitsize
            start_index = 1000 + (i - 10) * new_splitsize  # Adjust start index for new splitsize
        else:
            start_index = i * splitsize
        
        end_index = min(start_index + splitsize, total_rows)
        subdf = frequencydf[start_index:end_index][columns]
        subdf.to_csv(language + '/Vocabulary/Split_Sets/' + str(start_index) + '-' + str(end_index) + '.csv')
        
        i += 1
    
    remainder = total_rows % splitsize
    print('remainder=', remainder)
    if remainder > 0:
        remaindersubdf = frequencydf[-remainder:][columns]
        remaindersubdf.to_csv(language + '/Vocabulary/Split_Sets/' + 'Remainder.csv')

    return subdf

# Example usage
df = split_into_studysets(frequencydf, language=language)
# Out:
# columns: ['Spanish', 'show', 'lemma']
# remainder= 9

# %% [markdown]
# If you only want to do a subset of files for time purposes

# %%
def move_unselected_files(language, selected_files):
    # Create directory for spare sets
    spare_split_sets_dir = os.path.join(language, 'Vocabulary', 'Spare_Split_Sets')
    os.makedirs(spare_split_sets_dir, exist_ok=True)

    split_sets_dir = os.path.join(language, 'Vocabulary', 'Split_Sets')
    all_files = os.listdir(split_sets_dir)
    selected_files_set = set(selected_files)

    # Move files not in selected_files to the spare sets directory
    for file_name in all_files:
        if file_name not in selected_files_set:
            os.rename(
                os.path.join(split_sets_dir, file_name),
                os.path.join(spare_split_sets_dir, file_name)
            )
  # example of selected files
move_unselected_files(language, selected_files)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 18
#      13             os.rename(
#      14                 os.path.join(split_sets_dir, file_name),
#      15                 os.path.join(spare_split_sets_dir, file_name)
#      16             )
#      17   # example of selected files
# ---> 18 move_unselected_files(language, selected_files)
#
# Cell In[47], line 8, in move_unselected_files(language, selected_files)
#       6 split_sets_dir = os.path.join(language, 'Vocabulary', 'Split_Sets')
#       7 all_files = os.listdir(split_sets_dir)
# ----> 8 selected_files_set = set(selected_files)
#      10 # Move files not in selected_files to the spare sets directory
#      11 for file_name in all_files:
#
# TypeError: 'str' object is not callable

# %% [markdown]
# CHATGPT

# %%
CHATGPT_todosets = get_sets_to_do('ChatGPT_Sets')
# Out:
# Done: ['1100-1200.csv', '1700-1800.csv', '1800-1900.csv', '1600-1700.csv', '1400-1500.csv', '2750-3000.csv', '1300-1400.csv', '2500-2750.csv', '1900-2000.csv', '2250-2500.csv', '1500-1600.csv', '1200-1300.csv', '2000-2250.csv', '1000-1100.csv']
# To Do: ['800-900.csv', '100-200.csv', '600-700.csv', '700-800.csv', '0-100.csv', '300-400.csv', '900-1000.csv', '400-500.csv', '500-600.csv', '200-300.csv']

# %%
pd.isna(frequencydf.lemma[0])
# Out:
# False

# %%
def generate_sentence_in_target_language(variable_word, words_to_include, model = 'gpt-4o-2024-05-13', POS = 'None', tenses = [], lemma = 'None'):
    """
    Generate a sentence in lang using a specific word and part of speech, with words from a limited vocabulary, along with its English translation.

    Parameters:
    variable_word (str): The word to include in the sentence.
    POS (str): The part of speech the word should operate as.
    words_to_include (tuple): A list of words to try to include, and how many
    model (str): The model to use for generating the sentence (default is 'gpt-4o-2024-05-13').
    # tenses (list)

    Returns:
    str: A sentence in lang and its English translation, separated by a newline.
    """
    words_to_include = list(words_to_include[0].sample(words_to_include[1], replace=False))
    print(variable_word, words_to_include)
    if POS == 'None':
        if lemma != 'None':
            if not pd.isna(lemma):
                print(lemma)
                prompt = (
                      # f"Use only the following Russian words: {vocabulary_str}. "
                
                      f"Create a simple sentence in f{language} using basic vocabulary and containing the word '{variable_word}' "
                      f"({lemma}). Also, provide the English translation of the sentence separated by a newline."
                      f"Try to include the following words in the sentence: {words_to_include}"
                      )
            else:
                print('nolemma')
                prompt= (f"Create a simple sentence in f{language} using basic vocabulary and containing the word '{variable_word}' "
                ". Also, provide the English translation of the sentence separated by a newline."
                f"Try to include the following words in the sentence: {words_to_include}"
                         )
        
    else:
        print(POS)
        prompt = (
              f"Create a simple sentence in f{language} using basic vocabulary and containing the word '{variable_word}' "
              f"operating as a {POS} part of speech. Also, provide the English translation of the sentence separated by a newline."
              f"Try to include the following words in the sentence: {words_to_include}"
              # f"Use only the following tenses: {tenses}. "
              )
        
        if len(tenses) > 0:
            prompt += f"\n use only the following tenses: {tenses}"

    try:
        # Make the API request
        response = client.chat.completions.create(
            model=model,
            messages=[{"role": "user", "content": prompt}],
            max_tokens=50,
            temperature=0.2,
        )

        # Extract and return the output
        output_message = response.choices[0].message.content.strip()
        return output_message

    except Exception as e:
        return f"An error occurred: {str(e)}"

    # Extract and return the output
    output_message = response.choices[0].message.content.strip()
    return output_message

# %%
#TEST THE API
# frequencydf.columns
 
for index, row in frequencydf.iloc[304:308].iterrows():
    sentence = generate_sentence_in_target_language(row[language], (frequencydf.iloc[300:400][language], 2), lemma = row['lemma'])
    print(sentence)
# Out:
# suerte ['vete', 'noches']
# suerte
# Vete a dormir, que tengas buenas noches y mucha suerte.
#
# Go to sleep, have a good night and good luck.
# eh ['cuenta', 'capitán']
# eh
# ¿Te diste cuenta, eh, capitán?
# Did you notice, eh, captain?
# rápido ['camino', 'caso']
# rápido
# El camino es rápido en este caso.
# The road is quick in this case.
# cuenta ['guerra', 'adiós']
# contar
# El soldado cuenta historias de la guerra antes de decir adiós.
# The soldier tells stories of the war before saying goodbye.

# %%
def chatonset(s_set_df, set_name, n = 2):
    words_to_include = (s_set_df[language], n)
    s_set_df['ChatGPT_Sentence'] = s_set_df.apply(lambda row: generate_sentence_in_target_language(row[language], words_to_include, lemma = row['lemma']), axis = 1)
    s_set_df.to_csv(os.path.join(language, 'Vocabulary','ChatGPT_Sets', set_name))
    return s_set_df

# %%
def do_all_sets(post_directory, func, language = language):
    os.makedirs(os.path.join(language, 'Vocabulary', post_directory), exist_ok = True)
    allsets = os.listdir(os.path.join(language, 'Vocabulary', 'split_sets'))
    todosets = get_sets_to_do(post_directory)
    for s_set in todosets:
        if s_set[0] != '.':
        # # if s_set == '500-600.csv':
        #     # print(s_set)
            s_set_df = pd.read_csv(
                os.path.join(language, 'Vocabulary', 'split_sets', s_set)
            )
            print(s_set_df)
            print(s_set)
            func(s_set_df, s_set)
    return

# %%
do_all_sets('ChatGPT_Sets', chatonset)
# Out:
# Done: ['1100-1200.csv', '1700-1800.csv', '1800-1900.csv', '1600-1700.csv', '1400-1500.csv', '2750-3000.csv', '1300-1400.csv', '2500-2750.csv', '1900-2000.csv', '2250-2500.csv', '1500-1600.csv', '1200-1300.csv', '2000-2250.csv', '1000-1100.csv']
# To Do: ['800-900.csv', '100-200.csv', '600-700.csv', '700-800.csv', '0-100.csv', '300-400.csv', '900-1000.csv', '400-500.csv', '500-600.csv', '200-300.csv']
#     Unnamed: 0   Spanish                show     lemma
# 0          800  ejército            ejército  ejército
# 1          801    futuro              futuro    futuro
# 2          802    llevar              llevar    llevar
# 3          803  compañía            compañía  compañía
# 4          804    venido    *venido* (venir)     venir
# ..         ...       ...                 ...       ...
# 95         895     pagar               pagar     pagar
# 96         896     fotos      *fotos* (foto)      foto
# 97         897    centro              centro    centro
# 98         898    centro  *centro* (centrar)   centrar
# 99         899    supone  *supone* (suponer)   suponer
#
# [100 rows x 4 columns]
# 800-900.csv
# ejército ['pena', 'sistema']
# ejército
# futuro ['fuiste', 'señorita']
# futuro
# llevar ['centro', 'negocio']
# llevar
# compañía ['cambiar', 'empezar']
# compañía
# venido ['ocurre', 'entra']
# venir
# listos ['estúpido', 'permiso']
# listo
# haremos ['suena', 'fuiste']
# hacer
# sitio ['pena', 'anda']
# sitio
# verlo ['llamada', 'línea']
# ver
# puesto ['sistema', 'vio']
# puesto
# puesto ['ocurre', 'mensaje']
# poner
# atención ['fuiste', 'error']
# atención
# sino ['sistema', 'sean']
# sino
# cambiar ['pena', 'pase']
# cambiar
# error ['encontré', 'puesto']
# error
# blanco ['atención', 'sitio']
# blanco
# raro ['lindo', 'ocurre']
# raro
# palabras ['permiso', 'mente']
# palabra
# llegó ['fuiste', 'lindo']
# llegar
# sal ['mató', 'pase']
# sal
# sal ['entendido', 'imposible']
# salir
# pase ['entra', 'ganar']
# pasar
# mente ['haremos', 'foto']
# mente
# sistema ['barco', 'mitad']
# sistema
# película ['error', 'negocio']
# película
# anda ['novia', 'anda']
# andar
# ello ['normal', 'espere']
# ello
# negocio ['sistema', 'sal']
# negocio
# negocio ['pena', 'foto']
# negociar
# novia ['piso', 'pena']
# novia
# permiso ['creí', 'puesto']
# permiso
# creí ['mató', 'navidad']
# creer
# suena ['llevar', 'abre']
# sonar
# ocurre ['puesto', 'abre']
# ocurrir
# oficial ['sino', 'palabras']
# oficial
# espere ['llegó', 'blanco']
# esperar
# aire ['ganar', 'listos']
# aire
# mató ['pena', 'mitad']
# matar
# regresar ['centro', 'negocio']
# regresar
# vio ['mató', 'trasero']
# ver
# hazlo ['ejército', 'eras']
# hacer
# trasero ['tras', 'aire']
# trasero
# grupo ['película', 'abre']
# grupo
# entendido ['decirle', 'grupo']
# entender
# señorita ['compañía', 'haremos']
# señorita
# música ['listos', 'mató']
# música
# perra ['atención', 'tras']
# perra
# conoce ['mató', 'señorita']
# conocer
# empezar ['segundos', 'hazlo']
# empezar
# siente ['centro', 'llevar']
# sentir
# siente ['sal', 'trasero']
# sentar
# acabo ['raro', 'ejército']
# acabar
# estúpido ['compañía', 'mente']
# estúpido
# diferente ['futuro', 'accidente']
# diferente
# traje ['sino', 'vio']
# traer
# traje ['traje', 'raro']
# traje
# modo ['pase', 'acabo']
# modo
# encontré ['conoce', 'vio']
# encontrar
# mensaje ['mensaje', 'encontré']
# mensaje
# llamada ['centro', 'largo']
# llamada
# llamada ['línea', 'regresar']
# llamar
# navidad ['podríamos', 'normal']
# navidad
# eras ['conoce', 'estúpido']
# ser
# pena ['navidad', 'ganar']
# pena
# pena ['sal', 'hazlo']
# penar
# largo ['piso', 'funciona']
# largo
# largo ['decirle', 'llamada']
# largar
# entra ['entra', 'diferente']
# entrar
# piso ['error', 'centro']
# piso
# piso ['siente', 'trasero']
# pisar
# foto ['aire', 'fuiste']
# foto
# dijeron ['pena', 'mató']
# decir
# médico ['oficial', 'pena']
# médico
# accidente ['pena', 'foto']
# accidente
# fuiste ['decirle', 'negocio']
# ir
# fuiste ['navidad', 'palabras']
# ser
# imposible ['programa', 'navidad']
# imposible
# podríamos ['hazlo', 'ejército']
# poder
# línea ['largo', 'fuiste']
# línea
# propia ['acabo', 'mató']
# propio
# barco ['segundos', 'fuiste']
# barco
# ganar ['decirle', 'pena']
# ganar
# normal ['fuiste', 'lindo']
# normal
# segundos ['novia', 'diferente']
# segundo
# vive ['entendido', 'ello']
# vivir
# mitad ['conoce', 'sal']
# mitad
# quiera ['médico', 'podríamos']
# querer
# tras ['llegó', 'regresar']
# tras
# decirle ['empezar', 'llamada']
# decir
# lindo ['empezar', 'negocio']
# lindo
# funciona ['sitio', 'negocio']
# funcionar
# programa ['sal', 'lindo']
# programa
# vine ['largo', 'propia']
# venir
# abre ['grupo', 'piso']
# abrir
# sean ['siente', 'verlo']
# ser
# pagar ['conoce', 'mensaje']
# pagar
# fotos ['normal', 'listos']
# foto
# centro ['eras', 'traje']
# centro
# centro ['empezar', 'ejército']
# centrar
# supone ['médico', 'sino']
# suponer
#     Unnamed: 0  Spanish                 show    lemma
# 0          100   tiempo               tiempo   tiempo
# 1          101   verdad               verdad   verdad
# 2          102   estaba     *estaba* (estar)    estar
# 3          103    mejor                mejor    mejor
# 4          104    están      *están* (estar)    estar
# ..         ...      ...                  ...      ...
# 95         195   estado     *estado* (estar)    estar
# 96         196   estado               estado   estado
# 97         197   podría     *podría* (poder)    poder
# 98         198  acuerdo  *acuerdo* (acordar)  acordar
# 99         199  acuerdo              acuerdo  acuerdo
#
# [100 rows x 4 columns]
# 100-200.csv
# tiempo ['otro', 'nadie']
# tiempo
# verdad ['estar', 'podría']
# verdad
# estaba ['trabajo', 'seguro']
# estar
# mejor ['estado', 'dije']
# mejor
# están ['hasta', 'puedes']
# estar
# va ['mañana', 'tal']
# ir
# hombre ['claro', 'sin']
# hombre
# usted ['estar', 'siempre']
# usted
# mucho ['hombre', 'mí']
# mucho
# hace ['has', 'cosas']
# hacer
# entonces ['estaba', 'fuera']
# entonces
# siento ['hasta', 'mucho']
# sentir
# siento ['claro', 'quiere']
# sentar
# tenemos ['nosotros', 'claro']
# tener
# puedes ['otro', 'estado']
# poder
# ahí ['donde', 'desde']
# ahí
# ti ['solo', 'hablar']
# ti
# vida ['seguro', 'noche']
# vida
# ver ['fuera', 'siempre']
# ver
# alguien ['han', 'vida']
# alguien
# sr ['hablar', 'ahí']
# señor
# hasta ['espera', 'sr']
# hasta
# sin ['sobre', 'trabajo']
# sin
# mí ['siento', 'sr']
# mí
# solo ['otro', 'entonces']
# solo
# años ['pasa', 'poco']
# año
# sobre ['les', 'uno']
# sobre
# decir ['ver', 'ahí']
# decir
# uno ['hablar', 'nosotros']
# uno
# siempre ['tiempo', 'siento']
# siempre
# oh ['otro', 'donde']
# oh
# ir ['verdad', 'tipo']
# ir
# cosas ['has', 'están']
# cosa
# cosas ['ti', 'quiere']
# coser
# también ['mí', 'fuera']
# también
# antes ['necesito', 'lugar']
# antes
# has ['momento', 'estaba']
# haber
# ni ['quiere', 'años']
# ni
# mis ['les', 'siempre']
# mi
# día ['hace', 'siento']
# día
# estar ['tenemos', 'cosas']
# estar
# estamos ['estaba', 'después']
# estar
# noche ['estaba', 'han']
# noche
# nadie ['nosotros', 'padre']
# nadie
# otra ['momento', 'usted']
# otro
# quiere ['también', 'vida']
# querer
# parece ['entonces', 'fuera']
# parecer
# nosotros ['hasta', 'tipo']
# nosotros
# poco ['siempre', 'decir']
# poco
# padre ['hecho', 'quiere']
# padre
# trabajo ['hijo', 'uno']
# trabajo
# trabajo ['puedes', 'sabe']
# trabajar
# gente ['después', 'hecho']
# gente
# mira ['siento', 'entonces']
# mirar
# vas ['podemos', 'siempre']
# ir
# sea ['después', 'les']
# ser
# les ['después', 'quiere']
# les
# donde ['nosotros', 'tus']
# donde
# mismo ['mí', 'mañana']
# mismo
# hecho ['momento', 'fuera']
# hacer
# hecho ['necesito', 'les']
# hecho
# ellos ['pasa', 'usted']
# ellos
# dijo ['mucho', 'estar']
# decir
# pasa ['están', 'amigo']
# pasar
# dinero ['ver', 'va']
# dinero
# hijo ['hecho', 'gente']
# hijo
# tal ['fuera', 'podemos']
# tal
# otro ['acuerdo', 'hombre']
# otro
# hablar ['otra', 'mañana']
# hablar
# seguro ['padre', 'cosas']
# seguro
# claro ['dinero', 'hijo']
# claro
# estas ['siento', 'podría']
# este
# lugar ['ver', 'mundo']
# lugar
# mundo ['vida', 'ni']
# mundo
# amigo ['tipo', 'vida']
# amigo
# espera ['cosa', 'mí']
# esperar
# espera ['seguro', 'siento']
# espera
# mierda ['dijo', 'quiere']
# mierda
# han ['ni', 'después']
# haber
# tus ['hecho', 'sabe']
# tu
# sabe ['vas', 'hecho']
# saber
# después ['otro', 'claro']
# después
# momento ['estar', 'estaba']
# momento
# desde ['mismo', 'después']
# desde
# fuera ['fuera', 'mierda']
# fuera
# fuera ['tus', 'les']
# ir
# fuera ['hecho', 'mañana']
# ser
# cosa ['verdad', 'noche']
# cosa
# cosa ['ver', 'también']
# coser
# tipo ['trabajo', 'ahí']
# tipo
# mañana ['sea', 'oh']
# mañana
# podemos ['noche', 'cosa']
# poder
# dije ['estas', 'también']
# decir
# gran ['cosa', 'sabe']
# grande
# necesito ['estar', 'vida']
# necesitar
# estado ['siempre', 'sr']
# estar
# estado ['ver', 'mira']
# estado
# podría ['hijo', 'tus']
# poder
# acuerdo ['cosa', 'han']
# acordar
# acuerdo ['oh', 'usted']
# acuerdo
#     Unnamed: 0     Spanish                      show      lemma
# 0          600      seguir                    seguir     seguir
# 1          601      pueblo                    pueblo     pueblo
# 2          602       tenga           *tenga* (tener)      tener
# 3          603  caballeros  *caballeros* (caballero)  caballero
# 4          604      idiota                    idiota     idiota
# ..         ...         ...                       ...        ...
# 95         695     oficina                   oficina    oficina
# 96         696      hablas         *hablas* (hablar)     hablar
# 97         697      hablas          *hablas* (habla)      habla
# 98         698       libre                     libre      libre
# 99         699      agente                    agente     agente
#
# [100 rows x 4 columns]
# 600-700.csv
# seguir ['control', 'pequeña']
# seguir
# pueblo ['diré', 'conoces']
# pueblo
# tenga ['cambio', 'último']
# tener
# caballeros ['querida', 'digas']
# caballero
# idiota ['agente', 'disculpe']
# idiota
# dio ['hospital', 'nuestras']
# dar
# minuto ['lleva', 'peor']
# minuto
# bebé ['mucha', 'querida']
# bebé
# única ['peor', 'coche']
# único
# lejos ['pueblo', 'control']
# lejos
# nuestras ['acerca', 'dormir']
# nuestro
# plan ['gusto', 'último']
# plan
# pienso ['pueblo', 'presidente']
# pensar
# sentido ['seguir', 'diré']
# sentido
# sentido ['hacemos', 'vámonos']
# sentir
# dormir ['queremos', 'acerca']
# dormir
# digas ['libre', 'nuestras']
# decir
# palabra ['peor', 'falta']
# palabra
# correcto ['correcto', 'increíble']
# correcto
# control ['diciendo', 'os']
# control
# vemos ['querida', 'extraño']
# ver
# entiendes ['cambio', 'perfecto']
# entender
# país ['disculpe', 'cielo']
# país
# seis ['control', 'nuestras']
# seis
# último ['vemos', 'país']
# último
# ésta ['cállate', 'cambio']
# ésta
# diga ['os', 'pienso']
# decir
# podrías ['odio', 'calle']
# poder
# pequeña ['sucede', 'especial']
# pequeña
# cállate ['caballeros', 'vámonos']
# callar
# trato ['odio', 'rey']
# trato
# trato ['palabra', 'libro']
# tratar
# rey ['peor', 'tenga']
# rey
# sucede ['general', 'especial']
# suceder
# muchachos ['anoche', 'sucede']
# muchacho
# jamás ['cállate', 'oficina']
# jamás
# cama ['control', 'lleva']
# cama
# srta ['además', 'rey']
# señorita
# ayudar ['cama', 'cállate']
# ayudar
# acerca ['hacemos', 'tenga']
# acerca
# acerca ['os', 'buscar']
# acercar
# di ['sentido', 'minuto']
# dar
# cambio ['odio', 'presidente']
# cambio
# cambio ['hacemos', 'odio']
# cambiar
# falta ['general', 'nuestras']
# falta
# falta ['vámonos', 'acerca']
# faltar
# hospital ['dormir', 'vemos']
# hospital
# lleva ['peor', 'mucha']
# llevar
# presidente ['sentido', 'cállate']
# presidente
# mil ['presidente', 'mil']
# mil
# gusto ['seguir', 'odio']
# gusto
# gusto ['pueblo', 'agente']
# gustar
# conoces ['mucha', 'nuestras']
# conocer
# diciendo ['muchachos', 'di']
# decir
# os ['ido', 'odio']
# os
# ido ['calle', 'libro']
# ir
# general ['calle', 'trato']
# general
# extraño ['trato', 'coche']
# extraño
# extraño ['peor', 'acerca']
# extrañar
# semanas ['libre', 'correcto']
# semana
# coche ['agente', 'os']
# coche
# peor ['cambio', 'cambio']
# peor
# peor ['presidente', 'coche']
# bien
# mucha ['perder', 'ayudar']
# mucho
# disculpe ['increíble', 'habrá']
# disculpar
# diré ['muchachos', 'acerca']
# decir
# anoche ['agente', 'podrías']
# anoche
# perder ['extraño', 'trato']
# perder
# vámonos ['trato', 'digas']
# ir
# nave ['caballeros', 'sentido']
# nave
# cielo ['calle', 'pienso']
# cielo
# habrá ['lleva', 'dormir']
# haber
# orden ['querida', 'podrías']
# orden
# segura ['extraño', 'tenga']
# seguro
# querida ['dormir', 'presidente']
# querida
# querida ['increíble', 'diciendo']
# querido
# querida ['sentido', 'acerca']
# querer
# niña ['idiota', 'correcto']
# niña
# increíble ['hacemos', 'general']
# increíble
# además ['sucede', 'ido']
# además
# deben ['jamás', 'especial']
# deber
# libro ['minuto', 'irme']
# libro
# calle ['podrías', 'correcto']
# calle
# calle ['cambio', 'pienso']
# callar
# café ['os', 'diré']
# café
# piensas ['odio', 'cama']
# pensar
# hacemos ['extraño', 'querida']
# hacer
# especial ['vámonos', 'minuto']
# especial
# queremos ['querida', 'vemos']
# querer
# irme ['especial', 'país']
# ir
# perfecto ['vámonos', 'caballeros']
# perfecto
# buscar ['además', 'hospital']
# buscar
# odio ['hospital', 'perder']
# odio
# odio ['seis', 'querida']
# odiar
# piensa ['conoces', 'diciendo']
# pensar
# oficina ['diga', 'gusto']
# oficina
# hablas ['nuestras', 'querida']
# hablar
# hablas ['anoche', 'podrías']
# habla
# libre ['seis', 'diré']
# libre
# agente ['acerca', 'acerca']
# agente
#     Unnamed: 0   Spanish                   show     lemma
# 0          700    llamar                 llamar    llamar
# 1          701      mala          *mala* (malo)      malo
# 2          702      mala                   mala      mala
# 3          703    detrás                 detrás    detrás
# 4          704     viste          *viste* (ver)       ver
# ..         ...       ...                    ...       ...
# 95         795   derecho                derecho   derecho
# 96         796    placer                 placer    placer
# 97         797  recuerda  *recuerda* (recordar)  recordar
# 98         798    estuve       *estuve* (estar)     estar
# 99         799  tratando    *tratando* (tratar)    tratar
#
# [100 rows x 4 columns]
# 700-800.csv
# llamar ['resto', 'campo']
# llamar
# mala ['adentro', 'frente']
# malo
# mala ['sueño', 'prueba']
# mala
# detrás ['daño', 'campo']
# detrás
# viste ['acaba', 'llamado']
# ver
# dile ['estuve', 'haría']
# decir
# grandes ['acabó', 'dado']
# grande
# recuerdas ['perdido', 'sueño']
# recordar
# real ['ropa', 'oído']
# real
# estaban ['miren', 'millones']
# estar
# mía ['lamento', 'hará']
# mío
# frente ['recuerdas', 'campo']
# frente
# perdido ['daño', 'sientes']
# perder
# llamo ['ropa', 'estaban']
# llamar
# muertos ['probablemente', 'tonto']
# muerto
# millones ['tonto', 'encima']
# millón
# asesino ['real', 'quisiera']
# asesino
# asesino ['resto', 'oído']
# asesinar
# sueño ['muertos', 'tonto']
# sueño
# sueño ['detrás', 'siendo']
# soñar
# quisiera ['usar', 'habría']
# querer
# habría ['habitación', 'ése']
# haber
# hará ['llamado', 'probablemente']
# hacer
# viaje ['tuyo', 'querido']
# viaje
# viaje ['usar', 'sientes']
# viajar
# probablemente ['mala', 'quisiera']
# probablemente
# resto ['preguntas', 'perdido']
# resto
# estaré ['otras', 'resto']
# estar
# maldición ['encima', 'avión']
# maldición
# lamento ['sueño', 'prueba']
# lamento
# lamento ['llamar', 'daño']
# lamentar
# muchacho ['mala', 'recuerda']
# muchacho
# avión ['acabó', 'prueba']
# avión
# ropa ['información', 'perdido']
# ropa
# fuerza ['profesor', 'fuerza']
# fuerza
# fuerza ['siendo', 'asesino']
# forzar
# llamado ['quieras', 'secreto']
# llamado
# llamado ['llamado', 'grandes']
# llamar
# oído ['asesino', 'sientes']
# oído
# oído ['detrás', 'viaje']
# oír
# dado ['siendo', 'querido']
# dado
# dado ['llamado', 'maldición']
# dar
# encima ['acaba', 'avión']
# encima
# negro ['avión', 'profesor']
# negro
# usar ['tonto', 'muchacho']
# usar
# información ['ropa', 'viste']
# información
# uds ['llamo', 'muertos']
# ustedes
# preguntas ['oído', 'decirte']
# preguntar
# preguntas ['llamado', 'llamar']
# pregunta
# tuvo ['tranquilo', 'lamento']
# tener
# secreto ['dile', 'acaba']
# secreto
# vuelve ['grandes', 'habría']
# volver
# miren ['prueba', 'noticias']
# mirar
# quieras ['boca', 'haz']
# querer
# haría ['sueño', 'acabó']
# hacer
# acaba ['sientes', 'querido']
# acabar
# otras ['oído', 'placer']
# otro
# incluso ['profesor', 'mala']
# incluso
# sientes ['usar', 'derecho']
# sentir
# sientes ['sueño', 'hará']
# sentar
# deberíamos ['asesino', 'deberíamos']
# deber
# haz ['asunto', 'vuelve']
# hacer
# haz ['detrás', 'tonto']
# haz
# decirte ['daño', 'seas']
# decir
# boca ['placer', 'prueba']
# boca
# dolor ['sueño', 'decirte']
# dolor
# baño ['preguntas', 'fuerza']
# baño
# baño ['perdido', 'estuve']
# bañar
# adentro ['dolor', 'campo']
# adentro
# profesor ['quieras', 'llamar']
# profesor
# habitación ['baño', 'tonto']
# habitación
# daño ['adentro', 'poner']
# daño
# daño ['haría', 'quédate']
# dañar
# tuyo ['información', 'boca']
# tuyo
# seas ['mía', 'estuve']
# ser
# noticias ['asesino', 'prueba']
# noticia
# demás ['muertos', 'avión']
# demás
# querido ['secreto', 'querido']
# querido
# querido ['diez', 'adentro']
# querer
# duro ['campo', 'daño']
# duro
# duro ['acaba', 'oído']
# durar
# poner ['quisiera', 'miren']
# poner
# prueba ['siendo', 'placer']
# prueba
# prueba ['usar', 'mala']
# probar
# mire ['preguntas', 'secreto']
# mirar
# tonto ['otras', 'boca']
# tonto
# campo ['dolor', 'llamado']
# campo
# campo ['oído', 'encima']
# campar
# siendo ['dado', 'duro']
# ser
# diez ['haz', 'información']
# diez
# ése ['diez', 'demás']
# ese
# tranquilo ['fuerza', 'daño']
# tranquilo
# asunto ['demás', 'profesor']
# asunto
# acabó ['recuerda', 'campo']
# acabar
# quédate ['sueño', 'uds']
# quedar
# derecho ['adentro', 'mala']
# derecho
# placer ['haz', 'asunto']
# placer
# recuerda ['dolor', 'sientes']
# recordar
# estuve ['tranquilo', 'daño']
# estar
# tratando ['muchacho', 'estaré']
# tratar
#     Unnamed: 0 Spanish           show  lemma
# 0            0     que            que    que
# 1            1      de             de     de
# 2            2      no             no     no
# 3            3       a              a      a
# 4            4      la             la     la
# ..         ...     ...            ...    ...
# 95          95   favor          favor  favor
# 96          96     esa    *esa* (ese)    ese
# 97          97     dos            dos    dos
# 98          98     tan  *tan* (tanto)  tanto
# 99          99   señor          señor  señor
#
# [100 rows x 4 columns]
# 0-100.csv
# que ['un', 'en']
# que
# de ['por', 'yo']
# de
# no ['hacer', 'que']
# no
# a ['cuando', 'si']
# a
# la ['algo', 'o']
# la
# el ['algo', 'como']
# el
# es ['un', 'con']
# ser
# y ['o', 'qué']
# y
# en ['ahora', 'sabes']
# en
# lo ['se', 'está']
# lo
# un ['cuando', 'porque']
# un
# por ['favor', 'eres']
# por
# qué ['puedo', 'hola']
# qué
# me ['por', 'ya']
# me
# una ['casa', 'quién']
# un
# te ['a', 'así']
# te
# los ['ser', 'las']
# lo
# se ['gracias', 'quién']
# se
# con ['ese', 'dios']
# con
# para ['el', 'cómo']
# para
# mi ['eso', 'al']
# mi
# está ['con', 'algo']
# estar
# si ['no', 'nunca']
# si
# bien ['hola', 'él']
# bien
# pero ['pero', 'por']
# pero
# yo ['bien', 'tiene']
# yo
# eso ['casa', 'estoy']
# eso
# las ['hacer', 'algo']
# la
# sí ['ser', 'hola']
# sí
# su ['fue', 'el']
# su
# tu ['creo', 'para']
# tu
# aquí ['esa', 'el']
# aquí
# del ['sabes', 'nada']
# del
# al ['este', 'al']
# al
# como ['quién', 'esto']
# como
# como ['un', 'señor']
# comer
# le ['sus', 'o']
# le
# más ['tan', 'estoy']
# más
# esto ['dios', 'tiene']
# esto
# ya ['como', 'todos']
# ya
# todo ['fue', 'ya']
# todo
# esta ['quién', 'gracias']
# esta
# vamos ['hola', 'fue']
# ir
# muy ['vamos', 'muy']
# muy
# hay ['ha', 'su']
# haber
# ahora ['sólo', 'señor']
# ahora
# algo ['las', 'puedo']
# algo
# estoy ['se', 'qué']
# estar
# tengo ['tienes', 'los']
# tener
# nos ['así', 'bien']
# nos
# tú ['creo', 'eres']
# tú
# nada ['en', 'señor']
# nada
# cuando ['con', 'eres']
# cuando
# ha ['la', 'casa']
# haber
# este ['te', 'un']
# este
# sé ['y', 'los']
# saber
# estás ['al', 'tú']
# estar
# así ['sabes', 'bien']
# así
# puedo ['se', 'algo']
# poder
# cómo ['sabes', 'tan']
# cómo
# quiero ['todo', 'gracias']
# querer
# sólo ['del', 'sí']
# sólo
# soy ['le', 'en']
# ser
# tiene ['hay', 'lo']
# tener
# gracias ['cuando', 'está']
# gracias
# o ['tiene', 'como']
# o
# él ['quién', 'te']
# él
# bueno ['así', 'cómo']
# bueno
# fue ['cuando', 'casa']
# ser
# fue ['qué', 'aquí']
# ir
# ser ['su', 'era']
# ser
# hacer ['todo', 'la']
# hacer
# son ['casa', 'bueno']
# ser
# todos ['te', 'qué']
# todo
# era ['eso', 'ella']
# ser
# eres ['vez', 'esto']
# ser
# vez ['porque', 'del']
# vez
# tienes ['que', 'algo']
# tener
# creo ['esto', 'tú']
# creer
# ella ['vez', 'cuando']
# ella
# he ['tu', 'vez']
# haber
# ese ['soy', 'vez']
# ese
# voy ['como', 'de']
# ir
# puede ['ya', 'que']
# poder
# sabes ['estoy', 'yo']
# saber
# hola ['tiene', 'ahora']
# hola
# sus ['gracias', 'tu']
# su
# porque ['está', 'favor']
# porque
# dios ['una', 'mi']
# dios
# quién ['las', 'en']
# quién
# nunca ['todos', 'ahora']
# nunca
# dónde ['con', 'fue']
# dónde
# quieres ['aquí', 'puedo']
# querer
# casa ['algo', 'su']
# casa
# casa ['puede', 'algo']
# casar
# favor ['hola', 'de']
# favor
# esa ['hay', 'creo']
# ese
# dos ['este', 'más']
# dos
# tan ['ha', 'gracias']
# tanto
# señor ['tú', 'se']
# señor
#     Unnamed: 0 Spanish              show   lemma
# 0          300  puerta            puerta  puerta
# 1          301     ves       *ves* (ver)     ver
# 2          302    vaya       *vaya* (ir)      ir
# 3          303      ah                ah      ah
# 4          304  suerte            suerte  suerte
# ..         ...     ...               ...     ...
# 95         395  juntos  *juntos* (junto)   junto
# 96         396    dame      *dame* (dar)     dar
# 97         397   único             único   único
# 98         398  déjame  *déjame* (dejar)   dejar
# 99         399   cerca             cerca   cerca
#
# [100 rows x 4 columns]
# 300-400.csv
# puerta ['dicho', 'nueva']
# puerta
# ves ['toma', 'debes']
# ver
# vaya ['primero', 'déjame']
# ir
# ah ['primera', 'debemos']
# ah
# suerte ['suerte', 'quizás']
# suerte
# eh ['nueva', 'viene']
# eh
# rápido ['suerte', 'debería']
# rápido
# cuenta ['problemas', 'horas']
# contar
# cuenta ['mano', 'pasar']
# cuenta
# quizás ['vale', 'camino']
# quizás
# esas ['pensé', 'iba']
# ese
# pues ['todavía', 'nueva']
# pues
# pasado ['hice', 'ciudad']
# pasar
# pasado ['manos', 'cuenta']
# pasado
# pensé ['caso', 'ok']
# pensar
# todavía ['volver', 'todavía']
# todavía
# hermano ['ayuda', 'caso']
# hermano
# debes ['buenos', 'capitán']
# deber
# casi ['primero', 'sería']
# casi
# forma ['vale', 'debes']
# forma
# aqui ['muchas', 'noches']
# aquí
# chico ['todavía', 'toma']
# chico
# ok ['año', 'ayuda']
# ok
# dicho ['casi', 'primera']
# decir
# dicho ['mientras', 'haré']
# dicho
# nueva ['cuenta', 'nueva']
# nuevo
# nueva ['casi', 'hice']
# nueva
# sabía ['hermano', 'personas']
# saber
# muchas ['dicho', 'viene']
# mucho
# dentro ['guerra', 'nueva']
# dentro
# hice ['nueva', 'ah']
# hacer
# contra ['viejo', 'ayuda']
# contra
# auto ['mano', 'muerte']
# auto
# camino ['ves', 'problemas']
# camino
# camino ['vi', 'sería']
# caminar
# ayuda ['poder', 'ah']
# ayuda
# ayuda ['capitán', 'pasado']
# ayudar
# primera ['vete', 'hablando']
# primero
# primera ['vi', 'haré']
# primera
# hacia ['auto', 'noches']
# hacia
# vi ['loco', 'capitán']
# ver
# miedo ['quizás', 'primero']
# miedo
# adiós ['ayuda', 'contra']
# adiós
# primero ['hablando', 'primera']
# primero
# debería ['esposa', 'esposa']
# deber
# poder ['año', 'volver']
# poder
# niños ['esposa', 'debería']
# niño
# sería ['deja', 'camino']
# ser
# historia ['único', 'casi']
# historia
# hey ['pasado', 'capitán']
# hey
# mientras ['esposa', 'debería']
# mientras
# ciudad ['juntos', 'camino']
# ciudad
# dijiste ['dicho', 'da']
# decir
# espero ['ves', 'hablando']
# esperar
# cuánto ['pensé', 'primero']
# cuánto
# esposa ['vi', 'ah']
# esposa
# esposa ['semana', 'único']
# esposar
# pronto ['primera', 'casi']
# pronto
# chicos ['eh', 'capitán']
# chico
# cualquier ['pues', 'muchas']
# cualquier
# viejo ['cualquier', 'manos']
# viejo
# debemos ['forma', 'ayuda']
# deber
# deja ['mientras', 'dicho']
# dejar
# año ['buenos', 'cualquier']
# año
# muerte ['dicho', 'aqui']
# muerte
# hablando ['problemas', 'toma']
# hablar
# manos ['dijiste', 'único']
# mano
# da ['quizás', 'chicos']
# dar
# loco ['muchas', 'vete']
# loco
# problemas ['buenos', 'horas']
# problema
# mano ['cuenta', 'historia']
# mano
# guerra ['debes', 'esposa']
# guerra
# semana ['debería', 'muerte']
# semana
# pasar ['sabía', 'quizás']
# pasar
# vale ['muchas', 'ah']
# valer
# vale ['vi', 'esposa']
# vale
# cuál ['listo', 'cuánto']
# cuál
# viene ['pronto', 'pues']
# venir
# volver ['cuenta', 'ah']
# volver
# toma ['caso', 'personas']
# tomar
# caso ['noches', 'manos']
# caso
# caso ['dentro', 'primero']
# casar
# agua ['agua', 'pasado']
# agua
# haré ['cuál', 'dijiste']
# hacer
# vete ['pronto', 'déjame']
# ir
# entiendo ['todavía', 'ok']
# entender
# horas ['ayuda', 'problemas']
# hora
# personas ['cuenta', 'pues']
# persona
# capitán ['cuánto', 'pensé']
# capitán
# adelante ['pues', 'cuenta']
# adelante
# niño ['primera', 'noches']
# niño
# listo ['listo', 'historia']
# listo
# noches ['da', 'nueva']
# noche
# buenos ['pasar', 'vi']
# bueno
# iba ['niños', 'ah']
# ir
# juntos ['mano', 'pensé']
# junto
# dame ['mientras', 'suerte']
# dar
# único ['haré', 'déjame']
# único
# déjame ['chico', 'pasar']
# dejar
# cerca ['historia', 'agua']
# cerca
#     Unnamed: 0    Spanish                  show      lemma
# 0          900     basura                basura     basura
# 1          901  situación             situación  situación
# 2          902    mejores     *mejores* (mejor)      mejor
# 3          903     vienen      *vienen* (venir)      venir
# 4          904    encanta  *encanta* (encantar)   encantar
# ..         ...        ...                   ...        ...
# 95         995     propio                propio     propio
# 96         996        oro                   oro        oro
# 97         997        oro          *oro* (orar)       orar
# 98         998  enseguida             enseguida  enseguida
# 99         999      linda       *linda* (lindo)      lindo
#
# [100 rows x 4 columns]
# 900-1000.csv
# basura ['vista', 'das']
# basura
# situación ['conseguir', 'voz']
# situación
# mejores ['regreso', 'media']
# mejor
# vienen ['gracioso', 'honor']
# venir
# encanta ['tendrá', 'corre']
# encantar
# marido ['silencio', 'hablo']
# marido
# personal ['vienen', 'culo']
# personal
# maestro ['bonito', 'propio']
# maestro
# hambre ['vista', 'tengas']
# hambre
# ataque ['pelo', 'salvo']
# ataque
# ataque ['siéntate', 'silencio']
# atacar
# culo ['silencio', 'tenías']
# culo
# dale ['hablo', 'peligro']
# dar
# pie ['hicieron', 'baja']
# pie
# conseguir ['maestro', 'negocios']
# conseguir
# trabajando ['pelo', 'culo']
# trabajar
# gracioso ['vuelto', 'vista']
# gracioso
# dejó ['tipos', 'basura']
# dejar
# pudo ['corre', 'sale']
# poder
# derecha ['hotel', 'salvo']
# derecha
# izquierda ['llamas', 'sol']
# izquierda
# próxima ['sentir', 'derecha']
# próximo
# pobre ['próxima', 'dejó']
# pobre
# respuesta ['oro', 'tendrá']
# respuesta
# tipos ['oro', 'disculpa']
# tipo
# sentir ['baja', 'culo']
# sentir
# tenías ['nena', 'humano']
# tener
# pude ['dejó', 'ataque']
# poder
# darle ['llamas', 'oro']
# dar
# voz ['llamas', 'corre']
# voz
# amiga ['estaría', 'hotel']
# amiga
# gustan ['oro', 'amiga']
# gustar
# vista ['culo', 'negocios']
# vista
# vista ['ataque', 'humano']
# ver
# salvo ['vista', 'próxima']
# salvo
# salvo ['media', 'dejó']
# salvar
# loca ['vista', 'tendrá']
# loco
# hotel ['conseguir', 'ten']
# hotel
# hicieron ['negocios', 'llegado']
# hacer
# ten ['bonito', 'hambre']
# tener
# temo ['llamas', 'peligro']
# temer
# señal ['tengas', 'pelo']
# señal
# pelo ['simplemente', 'decirme']
# pelo
# pelo ['pobre', 'gracioso']
# pelar
# llevo ['voz', 'vienen']
# llevar
# ayer ['bonito', 'salvo']
# ayer
# das ['baja', 'temo']
# dar
# nena ['pobre', 'misión']
# nena
# servicio ['izquierda', 'trabajando']
# servicio
# tren ['amiga', 'enseguida']
# tren
# bonito ['llamas', 'tenías']
# bonito
# mes ['dan', 'basura']
# mes
# tendrá ['sol', 'servicio']
# tener
# tendrás ['ataque', 'mejores']
# tener
# edad ['vuelto', 'pude']
# edad
# ellas ['oro', 'sexo']
# ellas
# hermosa ['humano', 'vista']
# hermoso
# honor ['tendrá', 'señal']
# honor
# simplemente ['baja', 'gustan']
# simplemente
# llamas ['salvo', 'situación']
# llamar
# llamas ['divertido', 'tipos']
# llama
# tengas ['edad', 'llegado']
# tener
# corre ['señal', 'pie']
# correr
# baja ['oro', 'sol']
# bajo
# baja ['basura', 'estan']
# baja
# sol ['propio', 'ataque']
# sol
# siéntate ['simplemente', 'humano']
# sentar
# dan ['gracioso', 'culo']
# dar
# humano ['estaría', 'humano']
# humano
# divertido ['estaría', 'próxima']
# divertido
# divertido ['pelo', 'izquierda']
# divertir
# sexo ['salvo', 'disculpa']
# sexo
# vuelto ['nena', 'oro']
# vuelto
# vuelto ['servicio', 'silencio']
# volver
# peligro ['caja', 'pudo']
# peligro
# peligro ['ataque', 'salvo']
# peligrar
# mesa ['vuelto', 'vista']
# mesa
# siguiente ['vista', 'conseguir']
# siguiente
# hablo ['vuelto', 'decirme']
# hablar
# disculpa ['vuelto', 'das']
# disculpa
# disculpa ['tendrá', 'basura']
# disculpar
# decirme ['señal', 'tenías']
# decir
# caja ['mes', 'dejó']
# caja
# negocios ['caja', 'trabajando']
# negocio
# negocios ['mes', 'temo']
# negociar
# misión ['sentir', 'situación']
# misión
# silencio ['propio', 'ataque']
# silencio
# sale ['regreso', 'baja']
# salir
# llegado ['basura', 'temo']
# llegar
# estaría ['negocios', 'bonito']
# estar
# regreso ['humano', 'izquierda']
# regreso
# regreso ['hicieron', 'linda']
# regresar
# media ['llevo', 'servicio']
# media
# media ['humano', 'salvo']
# medio
# estan ['próxima', 'gustan']
# estar
# propio ['divertido', 'hablo']
# propio
# oro ['humano', 'respuesta']
# oro
# oro ['media', 'honor']
# orar
# enseguida ['pudo', 'divertido']
# enseguida
# linda ['nena', 'estaría']
# lindo
#     Unnamed: 0   Spanish                    show      lemma
# 0          400     cerca        *cerca* (cercar)     cercar
# 1          401     otros          *otros* (otro)       otro
# 2          402     sigue        *sigue* (seguir)     seguir
# 3          403    grande                  grande     grande
# 4          404    arriba                  arriba     arriba
# ..         ...       ...                     ...        ...
# 95         495  pregunta  *pregunta* (preguntar)  preguntar
# 96         496       fui              *fui* (ir)         ir
# 97         497       fui             *fui* (ser)        ser
# 98         498    cuatro                  cuatro     cuatro
# 99         499       sra          *sra* (señora)     señora
#
# [100 rows x 4 columns]
# 400-500.csv
# cerca ['llegar', 'realidad']
# cercar
# otros ['dices', 'puta']
# otro
# sigue ['justo', 'bajo']
# seguir
# grande ['amo', 'morir']
# grande
# arriba ['bajo', 'ay']
# arriba
# jefe ['dr', 'cuatro']
# jefe
# habla ['vuelta', 'corazón']
# hablar
# habla ['deberías', 'supuesto']
# habla
# supongo ['matar', 'significa']
# suponer
# manera ['necesitamos', 'comida']
# manera
# quieren ['clase', 'persona']
# querer
# feliz ['cuándo', 'cuatro']
# feliz
# significa ['durante', 'corazón']
# significar
# sangre ['manera', 'gustaría']
# sangre
# fin ['cerca', 'dices']
# fin
# bajo ['corazón', 'fin']
# bajar
# bajo ['cuatro', 'aunque']
# bajo
# llama ['morir', 'vuelta']
# llamar
# llama ['encontrar', 'cuatro']
# llama
# venir ['sigue', 'pregunta']
# venir
# morir ['sangre', 'necesita']
# morir
# importante ['cara', 'hubiera']
# importante
# hiciste ['dices', 'vuelta']
# hacer
# ojos ['cerca', 'grande']
# ojo
# escucha ['ojos', 'dicen']
# escuchar
# entrar ['tierra', 'segundo']
# entrar
# ningún ['habla', 'equipo']
# ninguno
# corazón ['sra', 'dejar']
# corazón
# diablos ['comida', 'feliz']
# diablo
# necesitamos ['persona', 'jefe']
# necesitar
# atrás ['segundo', 'deberías']
# atrás
# durante ['algunos', 'dicen']
# durante
# dices ['escucha', 'venga']
# decir
# nuestros ['corazón', 'haya']
# nuestro
# persona ['ojos', 'puta']
# persona
# abajo ['ningún', 'sigue']
# abajo
# dr ['conozco', 'equipo']
# doctor
# hija ['cree', 'habla']
# hija
# dejar ['necesita', 'pueda']
# dejar
# necesita ['cuándo', 'dices']
# necesitar
# llegar ['aunque', 'juego']
# llegar
# hago ['cuándo', 'ningún']
# hacer
# señora ['aunque', 'venga']
# señora
# haya ['unas', 'juego']
# haber
# haya ['igual', 'fui']
# haya
# suficiente ['ninguna', 'necesitamos']
# suficiente
# doctor ['ninguna', 'juego']
# doctor
# gustaría ['genial', 'hija']
# gustar
# tierra ['encontrar', 'pequeño']
# tierra
# cara ['hago', 'equipo']
# cara
# siquiera ['clase', 'durante']
# siquiera
# genial ['genial', 'ojos']
# genial
# cree ['suficiente', 'tomar']
# creer
# supuesto ['cara', 'dime']
# suponer
# tomar ['saben', 'unas']
# tomar
# equipo ['escucha', 'morir']
# equipo
# equipo ['cuándo', 'cree']
# equipar
# justo ['señora', 'dr']
# justo
# juego ['sangre', 'creer']
# juego
# juego ['doctor', 'sigue']
# jugar
# ninguna ['siquiera', 'pregunta']
# ninguno
# matar ['gustaría', 'señora']
# matar
# cinco ['haya', 'pueda']
# cinco
# dicen ['hago', 'grande']
# decir
# amo ['pregunta', 'atrás']
# amo
# amo ['hiciste', 'manera']
# amar
# cuándo ['abajo', 'tomar']
# cuándo
# pequeño ['amo', 'durante']
# pequeño
# algunos ['arriba', 'pregunta']
# alguno
# conozco ['encontrar', 'grande']
# conocer
# clase ['habla', 'fin']
# clase
# maldito ['haya', 'genial']
# maldito
# unas ['juego', 'cara']
# un
# muchos ['morir', 'haya']
# mucho
# hubiera ['saben', 'supuesto']
# haber
# segundo ['habla', 'conozco']
# segundo
# aunque ['sangre', 'cuatro']
# aunque
# pueda ['llama', 'deberías']
# poder
# dime ['hiciste', 'dices']
# decir
# igual ['necesitamos', 'unas']
# igual
# comida ['cuerpo', 'pregunta']
# comida
# comida ['hija', 'unas']
# comer
# ay ['abajo', 'entrar']
# ay
# cuerpo ['bajo', 'siquiera']
# cuerpo
# encontrar ['comida', 'cerca']
# encontrar
# fuerte ['amo', 'llama']
# fuerte
# vuelta ['fin', 'conozco']
# vuelta
# vuelta ['venir', 'dime']
# volver
# venga ['diablos', 'corazón']
# venir
# creer ['bajo', 'persona']
# creer
# realidad ['sra', 'corazón']
# realidad
# saben ['jefe', 'llama']
# saber
# puta ['saben', 'dejar']
# puta
# deberías ['suficiente', 'igual']
# deber
# pregunta ['equipo', 'igual']
# pregunta
# pregunta ['ninguna', 'cerca']
# preguntar
# fui ['dices', 'morir']
# ir
# fui ['cinco', 'abajo']
# ser
# cuatro ['llama', 'supuesto']
# cuatro
# sra ['clase', 'pregunta']
# señora
#     Unnamed: 0   Spanish                   show     lemma
# 0          500    primer     *primer* (primero)   primero
# 1          501  trabajar               trabajar  trabajar
# 2          502         e                *e* (y)         y
# 3          503     hagas        *hagas* (hacer)     hacer
# 4          504      alto                   alto      alto
# ..         ...       ...                    ...       ...
# 95         595   sabemos      *sabemos* (saber)     saber
# 96         596  recuerdo               recuerdo  recuerdo
# 97         597  recuerdo  *recuerdo* (recordar)  recordar
# 98         598       par                    par       par
# 99         599     joven                  joven     joven
#
# [100 rows x 4 columns]
# 500-600.csv
# primer ['esté', 'medio']
# primero
# trabajar ['padres', 'luz']
# trabajar
# e ['asi', 'perro']
# y
# hagas ['meses', 'pensar']
# hacer
# alto ['perro', 'fácil']
# alto
# maldita ['misma', 'perdón']
# maldito
# comer ['posible', 'chicas']
# comer
# número ['estuvo', 'verte']
# número
# dar ['hacen', 'posible']
# dar
# necesitas ['hacen', 'basta']
# necesitar
# oportunidad ['luz', 'misma']
# oportunidad
# punto ['vivir', 'sola']
# punto
# misma ['posible', 'esperar']
# mismo
# última ['posible', 'mujeres']
# último
# afuera ['punto', 'chicas']
# afuera
# mujeres ['vino', 'cual']
# mujer
# pensar ['vivo', 'maldita']
# pensar
# fueron ['cuarto', 'joven']
# ir
# fueron ['trabajar', 'basta']
# ser
# difícil ['difícil', 'escuela']
# difícil
# vivir ['paz', 'vivo']
# vivir
# paso ['hagas', 'éste']
# paso
# paso ['carajo', 'mujeres']
# pasar
# malo ['afuera', 'par']
# malo
# estabas ['pensar', 'perdón']
# estar
# vivo ['posible', 'éste']
# vivir
# vivo ['maldita', 'queda']
# vivo
# haga ['dar', 'hermana']
# hacer
# queda ['recuerdo', 'sabemos']
# quedar
# hijos ['bastante', 'afuera']
# hijo
# mayor ['cual', 'comer']
# mayor
# fiesta ['queda', 'perdón']
# fiesta
# hacen ['mujeres', 'preocupes']
# hacer
# medio ['afuera', 'culpa']
# medio
# algunas ['bastante', 'hijos']
# alguno
# basta ['paso', 'trata']
# bastar
# arma ['fiesta', 'par']
# arma
# arma ['teléfono', 'veras']
# armar
# vino ['arma', 'estuvo']
# venir
# vino ['armas', 'fuego']
# vino
# meses ['preocupes', 'misma']
# mes
# cuarto ['pensando', 'última']
# cuarto
# éste ['dar', 'chicas']
# este
# escuela ['vivo', 'arma']
# escuela
# esté ['podía', 'esperando']
# estar
# dólares ['fiesta', 'joven']
# dólar
# tío ['hermana', 'basta']
# tío
# posible ['tuve', 'dólares']
# posible
# tuve ['sabemos', 'tampoco']
# tener
# fácil ['vivo', 'murió']
# fácil
# preocupes ['basta', 'pasando']
# preocupar
# luz ['pasando', 'sabemos']
# luz
# eran ['mujeres', 'preocupes']
# ser
# carajo ['fuego', 'perro']
# carajo
# final ['tío', 'recuerdo']
# final
# lista ['pensar', 'adónde']
# lista
# lista ['trata', 'arma']
# listo
# trata ['sabemos', 'hermana']
# tratar
# armas ['final', 'vivir']
# arma
# armas ['paz', 'cual']
# armar
# hermana ['exactamente', 'recuerdo']
# hermana
# exactamente ['mayor', 'fiesta']
# exactamente
# chicas ['alto', 'perro']
# chica
# podía ['alto', 'eran']
# poder
# bastante ['haga', 'vino']
# bastante
# seguridad ['trabajar', 'carajo']
# seguridad
# pasando ['eran', 'última']
# pasar
# esperando ['alto', 'seguridad']
# esperar
# acá ['posible', 'bastante']
# acá
# teléfono ['veras', 'esté']
# teléfono
# perro ['vino', 'estará']
# perro
# fuego ['comer', 'culpa']
# fuego
# murió ['perdón', 'estabas']
# morir
# tampoco ['padres', 'oportunidad']
# tampoco
# sola ['jugar', 'esperar']
# solo
# estuvo ['queda', 'misma']
# estar
# verte ['fiesta', 'cuanto']
# ver
# iré ['hagas', 'malo']
# ir
# tenido ['perro', 'vino']
# tener
# culpa ['malo', 'carajo']
# culpa
# culpa ['iré', 'acá']
# culpar
# veras ['podía', 'murió']
# veras
# adónde ['paz', 'trata']
# adónde
# buscando ['escuela', 'arma']
# buscar
# cuanto ['demonios', 'hijos']
# cuanto
# padres ['cual', 'difícil']
# padre
# paz ['lista', 'adónde']
# paz
# demonios ['vivo', 'número']
# demonio
# estará ['fueron', 'seguridad']
# estar
# cual ['trata', 'pasando']
# cual
# perdón ['hermana', 'algunas']
# perdón
# asi ['fuego', 'final']
# así
# jugar ['carajo', 'acá']
# jugar
# pensando ['medio', 'tenido']
# pensar
# esperar ['necesitas', 'par']
# esperar
# sabemos ['chicas', 'carajo']
# saber
# recuerdo ['cuarto', 'lista']
# recuerdo
# recuerdo ['arma', 'recuerdo']
# recordar
# par ['luz', 'tío']
# par
# joven ['pensar', 'cual']
# joven
#     Unnamed: 0  Spanish              show    lemma
# 0          200     papá              papá     papá
# 1          201    tener             tener    tener
# 2          202     dice    *dice* (decir)    decir
# 3          203      mío               mío      mío
# 4          204    crees   *crees* (creer)    creer
# ..         ...      ...               ...      ...
# 95         295  cuidado           cuidado  cuidado
# 96         296     pasó    *pasó* (pasar)    pasar
# 97         297   buenas  *buenas* (bueno)    bueno
# 98         298    somos     *somos* (ser)      ser
# 99         299     amor              amor     amor
#
# [100 rows x 4 columns]
# 200-300.csv
# papá ['hombres', 'tenía']
# papá
# tener ['debe', 'mujer']
# tener
# dice ['cierto', 'policía']
# decir
# mío ['tres', 'haces']
# mío
# crees ['debe', 'quizá']
# creer
# buena ['entre', 'cuidado']
# bueno
# buena ['pueden', 'veo']
# buena
# gusta ['van', 'minutos']
# gustar
# nuestro ['quien', 'hizo']
# nuestro
# nuevo ['tarde', 'importa']
# nuevo
# será ['oye', 'mío']
# ser
# haciendo ['tres', 'buena']
# hacer
# días ['muerto', 'idea']
# día
# nombre ['debe', 'toda']
# nombre
# buen ['madre', 'oye']
# bueno
# había ['unos', 'debo']
# haber
# ven ['allí', 'tienen']
# ver
# ven ['todas', 'problema']
# venir
# tres ['cuidado', 'haber']
# tres
# menos ['veces', 'hemos']
# menos
# debe ['ven', 'cada']
# deber
# tenía ['demasiado', 'había']
# tener
# mal ['dice', 'gusta']
# mal
# conmigo ['mas', 'visto']
# conmigo
# madre ['buena', 'había']
# madre
# hoy ['hizo', 'será']
# hoy
# quien ['mío', 'chica']
# quien
# sido ['mujer', 'amor']
# ser
# mamá ['toda', 'ud']
# mamá
# tienen ['allí', 'hizo']
# tener
# luego ['parte', 'saber']
# luego
# todas ['entre', 'mujer']
# todo
# allí ['menos', 'sido']
# allí
# toda ['estos', 'tanto']
# todo
# hora ['idea', 'haber']
# hora
# mujer ['haciendo', 'hizo']
# mujer
# visto ['familia', 'hemos']
# ver
# haces ['mío', 'algún']
# hacer
# importa ['lado', 'alguna']
# importar
# contigo ['algún', 'serio']
# contigo
# ve ['ustedes', 'tarde']
# ver
# ve ['papá', 'menos']
# ir
# tarde ['chica', 'hombres']
# tarde
# tarde ['chica', 'mas']
# tardar
# oye ['buenas', 've']
# oír
# parte ['haciendo', 'unos']
# partir
# parte ['van', 'todas']
# parte
# haber ['mal', 'serio']
# haber
# hombres ['tarde', 'unos']
# hombre
# problema ['debe', 'chica']
# problema
# mas ['amor', 'allí']
# mas
# saber ['nuestro', 'parte']
# saber
# quería ['nombre', 'visto']
# querer
# aún ['buena', 'debo']
# aún
# veces ['digo', 'mujer']
# vez
# nuestra ['toda', 'haces']
# nuestro
# hacerlo ['mas', 'tarde']
# hacer
# cada ['demasiado', 'somos']
# cada
# hizo ['había', 'cierto']
# hacer
# veo ['realmente', 'mal']
# ver
# tanto ['allí', 'nuevo']
# tanto
# razón ['amigos', 'hombres']
# razón
# ustedes ['crees', 'buenas']
# usted
# idea ['hombres', 'familia']
# idea
# esos ['entre', 'importa']
# eso
# van ['idea', 'hizo']
# ir
# quizá ['cariño', 'cada']
# quizá
# debo ['saber', 'digo']
# deber
# alguna ['mas', 'sido']
# alguno
# cierto ['allá', 'digo']
# cierto
# ud ['pasó', 'nombre']
# usted
# muerto ['tarde', 'cuidado']
# muerto
# muerto ['hacerlo', 'hizo']
# morir
# unos ['buenas', 'será']
# un
# estos ['digo', 'madre']
# este
# salir ['amigos', 'hizo']
# salir
# policía ['hemos', 'saber']
# policía
# realmente ['alguna', 'unos']
# realmente
# demasiado ['hora', 'nombre']
# demasiado
# familia ['oye', 'hacerlo']
# familia
# pueden ['entre', 'alguna']
# poder
# cabeza ['crees', 'tanto']
# cabeza
# hemos ['oye', 'tenía']
# haber
# amigos ['muerto', 'ud']
# amigo
# chica ['oye', 'días']
# chico
# chica ['sido', 'nombre']
# chica
# cariño ['hoy', 'idea']
# cariño
# lado ['somos', 'oye']
# lado
# allá ['gusta', 'tarde']
# allá
# entre ['amigos', 'quizá']
# entre
# minutos ['haber', 'conmigo']
# minuto
# digo ['demasiado', 'veces']
# decir
# algún ['ve', 'quería']
# algún
# serio ['idea', 'allí']
# serio
# cuidado ['buenas', 'haciendo']
# cuidar
# cuidado ['cuidado', 'serio']
# cuidado
# pasó ['saber', 'nombre']
# pasar
# buenas ['hizo', 'cuidado']
# bueno
# somos ['lado', 'buena']
# ser
# amor ['ustedes', 'hacerlo']
# amor

# %% [markdown]
# ADD TRANSLATION INFORMATION:

# %%
def add_set_translation_information(s_set_df, set_name, code = language_code):
    chat = pd.read_csv(os.path.join(language, 'Vocabulary', 'ChatGPT_Sets', set_name))
    # Apply the translation
    if 'Translation' in chat.columns:
        if 'POS' in chat.columns:
            s_set_df = chat[[language, 'Translation']]
        
    else:
        s_set_df['Translation'] = s_set_df.apply(
            lambda row: GoogleTranslator(source= code, target='en').translate(row[language]), axis=1
        )

    # Save to CSV
    s_set_df.to_csv(os.path.join(language, 'Vocabulary/Translated Sets', set_name), index=False)
    return s_set_df

# %%
import spacy
nlp = spacy.load("es_core_news_sm")
def add_spacy_POS_info(s_set_filepath):
    s_set_df = pd.read_csv(s_set_filepath)
    if 'POS' in s_set_df.columns:
        pass
    else:
        # Custom mapping for more understandable POS descriptions
        pos_mapping = {
            'ADJ': 'Adjective',
            'ADP': 'Preposition',
            'ADV': 'Adverb',
            'AUX': 'Auxiliary',
            'CONJ': 'Conjunction',
            'CCONJ': 'Conjunction',
            'DET': 'Determiner',
            'INTJ': 'Interjection',
            'NOUN': 'Noun',
            'NUM': 'Numeral',
            'PART': 'Particle',
            'PRON': 'Pronoun',
            'PROPN': 'Proper noun',
            'PUNCT': 'Punctuation',
            'SCONJ': 'Conjunction',
            'SYM': 'Symbol',
            'VERB': 'Verb',
            'X': 'Other'
        }
        
        # Function to get POS, tag, and layman's description
        def get_pos_tag_layman(word):
            doc = nlp(word)
            pos, tag, layman_description = None, None, None
            for token in doc:
                pos = token.pos_
                tag = token.tag_
                layman_description = pos_mapping.get(pos, 'Unknown')
            return pos, tag, layman_description
        
        # Apply the function to each word in the DataFrame
        s_set_df[['SpaCy_POS', 'SpaCy_Tag', 'POS']] = s_set_df['Spanish'].apply(lambda word: pd.Series(get_pos_tag_layman(word)))
        s_set_df.to_csv(s_set_filepath)
    
    return s_set_df

# %%
translation_todosets = get_sets_to_do('Translated Sets')
# Out:
# Done: ['1100-1200.csv', '1700-1800.csv', '1800-1900.csv', '1600-1700.csv', '1400-1500.csv', '2750-3000.csv', '1300-1400.csv', '2500-2750.csv', '1900-2000.csv', '2250-2500.csv', '1500-1600.csv', '1200-1300.csv', '2000-2250.csv', '1000-1100.csv']
# To Do: ['800-900.csv', '100-200.csv', '600-700.csv', '700-800.csv', '0-100.csv', '300-400.csv', '900-1000.csv', '400-500.csv', '500-600.csv', '200-300.csv']

# %%
for set in translation_todosets:
    print(set)
    do_all_sets('Translated Sets', add_set_translation_information)
for set in os.listdir(os.path.join(language, 'Vocabulary', 'Translated Sets')):
    add_spacy_POS_info(os.path.join(language, 'Vocabulary', 'Translated Sets', set))
# Out:
# 800-900.csv
# Done: ['1100-1200.csv', '1700-1800.csv', '1800-1900.csv', '1600-1700.csv', '1400-1500.csv', '2750-3000.csv', '1300-1400.csv', '2500-2750.csv', '1900-2000.csv', '2250-2500.csv', '1500-1600.csv', '1200-1300.csv', '2000-2250.csv', '1000-1100.csv']
# To Do: ['800-900.csv', '100-200.csv', '600-700.csv', '700-800.csv', '0-100.csv', '300-400.csv', '900-1000.csv', '400-500.csv', '500-600.csv', '200-300.csv']
#     Unnamed: 0   Spanish                show     lemma
# 0          800  ejército            ejército  ejército
# 1          801    futuro              futuro    futuro
# 2          802    llevar              llevar    llevar
# 3          803  compañía            compañía  compañía
# 4          804    venido    *venido* (venir)     venir
# ..         ...       ...                 ...       ...
# 95         895     pagar               pagar     pagar
# 96         896     fotos      *fotos* (foto)      foto
# 97         897    centro              centro    centro
# 98         898    centro  *centro* (centrar)   centrar
# 99         899    supone  *supone* (suponer)   suponer
#
# [100 rows x 4 columns]
# 800-900.csv
#     Unnamed: 0  Spanish                 show    lemma
# 0          100   tiempo               tiempo   tiempo
# 1          101   verdad               verdad   verdad
# 2          102   estaba     *estaba* (estar)    estar
# 3          103    mejor                mejor    mejor
# 4          104    están      *están* (estar)    estar
# ..         ...      ...                  ...      ...
# 95         195   estado     *estado* (estar)    estar
# 96         196   estado               estado   estado
# 97         197   podría     *podría* (poder)    poder
# 98         198  acuerdo  *acuerdo* (acordar)  acordar
# 99         199  acuerdo              acuerdo  acuerdo
#
# [100 rows x 4 columns]
# 100-200.csv
#     Unnamed: 0     Spanish                      show      lemma
# 0          600      seguir                    seguir     seguir
# 1          601      pueblo                    pueblo     pueblo
# 2          602       tenga           *tenga* (tener)      tener
# 3          603  caballeros  *caballeros* (caballero)  caballero
# 4          604      idiota                    idiota     idiota
# ..         ...         ...                       ...        ...
# 95         695     oficina                   oficina    oficina
# 96         696      hablas         *hablas* (hablar)     hablar
# 97         697      hablas          *hablas* (habla)      habla
# 98         698       libre                     libre      libre
# 99         699      agente                    agente     agente
#
# [100 rows x 4 columns]
# 600-700.csv
#     Unnamed: 0   Spanish                   show     lemma
# 0          700    llamar                 llamar    llamar
# 1          701      mala          *mala* (malo)      malo
# 2          702      mala                   mala      mala
# 3          703    detrás                 detrás    detrás
# 4          704     viste          *viste* (ver)       ver
# ..         ...       ...                    ...       ...
# 95         795   derecho                derecho   derecho
# 96         796    placer                 placer    placer
# 97         797  recuerda  *recuerda* (recordar)  recordar
# 98         798    estuve       *estuve* (estar)     estar
# 99         799  tratando    *tratando* (tratar)    tratar
#
# [100 rows x 4 columns]
# 700-800.csv
#     Unnamed: 0 Spanish           show  lemma
# 0            0     que            que    que
# 1            1      de             de     de
# 2            2      no             no     no
# 3            3       a              a      a
# 4            4      la             la     la
# ..         ...     ...            ...    ...
# 95          95   favor          favor  favor
# 96          96     esa    *esa* (ese)    ese
# 97          97     dos            dos    dos
# 98          98     tan  *tan* (tanto)  tanto
# 99          99   señor          señor  señor
#
# [100 rows x 4 columns]
# 0-100.csv
#     Unnamed: 0 Spanish              show   lemma
# 0          300  puerta            puerta  puerta
# 1          301     ves       *ves* (ver)     ver
# 2          302    vaya       *vaya* (ir)      ir
# 3          303      ah                ah      ah
# 4          304  suerte            suerte  suerte
# ..         ...     ...               ...     ...
# 95         395  juntos  *juntos* (junto)   junto
# 96         396    dame      *dame* (dar)     dar
# 97         397   único             único   único
# 98         398  déjame  *déjame* (dejar)   dejar
# 99         399   cerca             cerca   cerca
#
# [100 rows x 4 columns]
# 300-400.csv
#     Unnamed: 0    Spanish                  show      lemma
# 0          900     basura                basura     basura
# 1          901  situación             situación  situación
# 2          902    mejores     *mejores* (mejor)      mejor
# 3          903     vienen      *vienen* (venir)      venir
# 4          904    encanta  *encanta* (encantar)   encantar
# ..         ...        ...                   ...        ...
# 95         995     propio                propio     propio
# 96         996        oro                   oro        oro
# 97         997        oro          *oro* (orar)       orar
# 98         998  enseguida             enseguida  enseguida
# 99         999      linda       *linda* (lindo)      lindo
#
# [100 rows x 4 columns]
# 900-1000.csv
#     Unnamed: 0   Spanish                    show      lemma
# 0          400     cerca        *cerca* (cercar)     cercar
# 1          401     otros          *otros* (otro)       otro
# 2          402     sigue        *sigue* (seguir)     seguir
# 3          403    grande                  grande     grande
# 4          404    arriba                  arriba     arriba
# ..         ...       ...                     ...        ...
# 95         495  pregunta  *pregunta* (preguntar)  preguntar
# 96         496       fui              *fui* (ir)         ir
# 97         497       fui             *fui* (ser)        ser
# 98         498    cuatro                  cuatro     cuatro
# 99         499       sra          *sra* (señora)     señora
#
# [100 rows x 4 columns]
# 400-500.csv
#     Unnamed: 0   Spanish                   show     lemma
# 0          500    primer     *primer* (primero)   primero
# 1          501  trabajar               trabajar  trabajar
# 2          502         e                *e* (y)         y
# 3          503     hagas        *hagas* (hacer)     hacer
# 4          504      alto                   alto      alto
# ..         ...       ...                    ...       ...
# 95         595   sabemos      *sabemos* (saber)     saber
# 96         596  recuerdo               recuerdo  recuerdo
# 97         597  recuerdo  *recuerdo* (recordar)  recordar
# 98         598       par                    par       par
# 99         599     joven                  joven     joven
#
# [100 rows x 4 columns]
# 500-600.csv
#     Unnamed: 0  Spanish              show    lemma
# 0          200     papá              papá     papá
# 1          201    tener             tener    tener
# 2          202     dice    *dice* (decir)    decir
# 3          203      mío               mío      mío
# 4          204    crees   *crees* (creer)    creer
# ..         ...      ...               ...      ...
# 95         295  cuidado           cuidado  cuidado
# 96         296     pasó    *pasó* (pasar)    pasar
# 97         297   buenas  *buenas* (bueno)    bueno
# 98         298    somos     *somos* (ser)      ser
# 99         299     amor              amor     amor
#
# [100 rows x 4 columns]
# 200-300.csv
# 100-200.csv
# Done: ['1100-1200.csv', '1700-1800.csv', '1800-1900.csv', '1600-1700.csv', '1400-1500.csv', '800-900.csv', '2750-3000.csv', '1300-1400.csv', '100-200.csv', '600-700.csv', '700-800.csv', '2500-2750.csv', '1900-2000.csv', '2250-2500.csv', '1500-1600.csv', '1200-1300.csv', '0-100.csv', '2000-2250.csv', '300-400.csv', '900-1000.csv', '400-500.csv', '500-600.csv', '1000-1100.csv', '200-300.csv']
# To Do: []
# 600-700.csv
# Done: ['1100-1200.csv', '1700-1800.csv', '1800-1900.csv', '1600-1700.csv', '1400-1500.csv', '800-900.csv', '2750-3000.csv', '1300-1400.csv', '100-200.csv', '600-700.csv', '700-800.csv', '2500-2750.csv', '1900-2000.csv', '2250-2500.csv', '1500-1600.csv', '1200-1300.csv', '0-100.csv', '2000-2250.csv', '300-400.csv', '900-1000.csv', '400-500.csv', '500-600.csv', '1000-1100.csv', '200-300.csv']
# To Do: []
# 700-800.csv
# Done: ['1100-1200.csv', '1700-1800.csv', '1800-1900.csv', '1600-1700.csv', '1400-1500.csv', '800-900.csv', '2750-3000.csv', '1300-1400.csv', '100-200.csv', '600-700.csv', '700-800.csv', '2500-2750.csv', '1900-2000.csv', '2250-2500.csv', '1500-1600.csv', '1200-1300.csv', '0-100.csv', '2000-2250.csv', '300-400.csv', '900-1000.csv', '400-500.csv', '500-600.csv', '1000-1100.csv', '200-300.csv']
# To Do: []
# 0-100.csv
# Done: ['1100-1200.csv', '1700-1800.csv', '1800-1900.csv', '1600-1700.csv', '1400-1500.csv', '800-900.csv', '2750-3000.csv', '1300-1400.csv', '100-200.csv', '600-700.csv', '700-800.csv', '2500-2750.csv', '1900-2000.csv', '2250-2500.csv', '1500-1600.csv', '1200-1300.csv', '0-100.csv', '2000-2250.csv', '300-400.csv', '900-1000.csv', '400-500.csv', '500-600.csv', '1000-1100.csv', '200-300.csv']
# To Do: []
# 300-400.csv
# Done: ['1100-1200.csv', '1700-1800.csv', '1800-1900.csv', '1600-1700.csv', '1400-1500.csv', '800-900.csv', '2750-3000.csv', '1300-1400.csv', '100-200.csv', '600-700.csv', '700-800.csv', '2500-2750.csv', '1900-2000.csv', '2250-2500.csv', '1500-1600.csv', '1200-1300.csv', '0-100.csv', '2000-2250.csv', '300-400.csv', '900-1000.csv', '400-500.csv', '500-600.csv', '1000-1100.csv', '200-300.csv']
# To Do: []
# 900-1000.csv
# Done: ['1100-1200.csv', '1700-1800.csv', '1800-1900.csv', '1600-1700.csv', '1400-1500.csv', '800-900.csv', '2750-3000.csv', '1300-1400.csv', '100-200.csv', '600-700.csv', '700-800.csv', '2500-2750.csv', '1900-2000.csv', '2250-2500.csv', '1500-1600.csv', '1200-1300.csv', '0-100.csv', '2000-2250.csv', '300-400.csv', '900-1000.csv', '400-500.csv', '500-600.csv', '1000-1100.csv', '200-300.csv']
# To Do: []
# 400-500.csv
# Done: ['1100-1200.csv', '1700-1800.csv', '1800-1900.csv', '1600-1700.csv', '1400-1500.csv', '800-900.csv', '2750-3000.csv', '1300-1400.csv', '100-200.csv', '600-700.csv', '700-800.csv', '2500-2750.csv', '1900-2000.csv', '2250-2500.csv', '1500-1600.csv', '1200-1300.csv', '0-100.csv', '2000-2250.csv', '300-400.csv', '900-1000.csv', '400-500.csv', '500-600.csv', '1000-1100.csv', '200-300.csv']
# To Do: []
# 500-600.csv
# Done: ['1100-1200.csv', '1700-1800.csv', '1800-1900.csv', '1600-1700.csv', '1400-1500.csv', '800-900.csv', '2750-3000.csv', '1300-1400.csv', '100-200.csv', '600-700.csv', '700-800.csv', '2500-2750.csv', '1900-2000.csv', '2250-2500.csv', '1500-1600.csv', '1200-1300.csv', '0-100.csv', '2000-2250.csv', '300-400.csv', '900-1000.csv', '400-500.csv', '500-600.csv', '1000-1100.csv', '200-300.csv']
# To Do: []
# 200-300.csv
# Done: ['1100-1200.csv', '1700-1800.csv', '1800-1900.csv', '1600-1700.csv', '1400-1500.csv', '800-900.csv', '2750-3000.csv', '1300-1400.csv', '100-200.csv', '600-700.csv', '700-800.csv', '2500-2750.csv', '1900-2000.csv', '2250-2500.csv', '1500-1600.csv', '1200-1300.csv', '0-100.csv', '2000-2250.csv', '300-400.csv', '900-1000.csv', '400-500.csv', '500-600.csv', '1000-1100.csv', '200-300.csv']
# To Do: []

# %% [markdown]
# Make into Quizlet

# %%
def make_quizlet_set(set_name):
    df = pd.read_csv(os.path.join(language, 'Vocabulary', 'ChatGPT_Sets', set_name))
    transdf = pd.read_csv(os.path.join(language, 'Vocabulary', 'Translated Sets', set_name))

    df['ChatGPT_Sentence'] = df['ChatGPT_Sentence'].apply(lambda x: re.sub(r'\n+', '\n', x))
    df['ChatGPT_Sentence'] = df['ChatGPT_Sentence'].str.replace(r'\(see[^)]*\)', '', regex=True)
    df['ChatGPT_Sentence'] = df['ChatGPT_Sentence'].str.strip()
    
    if 'show' in df.columns:
        df['quizlet'] = '*' + transdf['Translation'] + '*' + '\n' + df['ChatGPT_Sentence']
        df[language] = df['show']
    else:
        df['quizlet'] = df['POS'] + ' : ' + '*' + transdf['Translation'] + '*' + '\n' + df['ChatGPT_Sentence']

    df = df[[language, 'quizlet']]
    os.makedirs(os.path.join(language, 'Vocabulary', 'Quizlet Sets'), exist_ok=True)
    output_path = os.path.join(language, 'Vocabulary', 'Quizlet Sets', set_name.replace('.csv', '.txt'))

    # Saving the data to a tab-separated text file with 3 lines between each row
    with open(output_path, 'w', encoding='utf-8') as outfile:
        for index, row in df.iterrows():
            outfile.write(f"{row[language]}\t{row['quizlet']}\n\n\n")

    print(f"Text file saved to {output_path}")
    return df

# %%
def make_reverse_quizlet_set(set_name):
    df = pd.read_csv(os.path.join(language, 'Vocabulary', 'ChatGPT_Sets', set_name))
    transdf = pd.read_csv(os.path.join(language, 'Vocabulary', 'Translated Sets', set_name))

    df['ChatGPT_Sentence'] = df['ChatGPT_Sentence'].apply(lambda x: re.sub(r'\n+', '\n', x))

    # Removing text within parentheses that start with 'see'
    df['ChatGPT_Sentence'] = df['ChatGPT_Sentence'].str.replace(r'\(see[^)]*\)', '', regex=True).str.strip()
    
    df['quizlet_front'] = transdf['POS'] + ' : ' + '*' + transdf['Translation'] + '*'
    df['quizlet_back'] =  '*' + df[language] + '*' + '\n' + df['ChatGPT_Sentence']

    df = df[['quizlet_front', 'quizlet_back']]
    os.makedirs(os.path.join(language, 'Vocabulary', 'Reverse Quizlet Sets'), exist_ok=True)
    output_path = os.path.join(language, 'Vocabulary', 'Reverse Quizlet Sets', set_name.replace('.csv', '.txt'))

    # Saving the data to a tab-separated text file with 3 lines between each row
    with open(output_path, 'w', encoding='utf-8') as outfile:
        for index, row in df.iterrows():
            outfile.write(f"{row['quizlet_front']}\t{row['quizlet_back']}\n\n\n")

    print(f"Text file saved to {output_path}")
    return df

# %%
builtin_set = builtins.set
a = builtin_set(os.listdir(os.path.join(language, 'Vocabulary', 'ChatGPT_Sets')))
b = builtin_set(os.listdir(os.path.join(language, 'Vocabulary', 'Translated Sets')))
quizlet_todosets = a.intersection(b)
reverse_quizlet_todosets = quizlet_todosets

# %%
quizlet_todosets
for s_set in quizlet_todosets:
    make_quizlet_set(s_set)
for s_set in reverse_quizlet_todosets:
    make_reverse_quizlet_set(s_set)
# Out:
# Text file saved to Spanish/Vocabulary/Quizlet Sets/2750-3000.txt
# Text file saved to Spanish/Vocabulary/Quizlet Sets/2000-2250.txt
# Text file saved to Spanish/Vocabulary/Quizlet Sets/2500-2750.txt
# Text file saved to Spanish/Vocabulary/Quizlet Sets/1400-1500.txt
# Text file saved to Spanish/Vocabulary/Quizlet Sets/900-1000.txt
# Text file saved to Spanish/Vocabulary/Quizlet Sets/1800-1900.txt
# Text file saved to Spanish/Vocabulary/Quizlet Sets/600-700.txt
# Text file saved to Spanish/Vocabulary/Quizlet Sets/1000-1100.txt
# Text file saved to Spanish/Vocabulary/Quizlet Sets/700-800.txt
# Text file saved to Spanish/Vocabulary/Quizlet Sets/400-500.txt
# Text file saved to Spanish/Vocabulary/Quizlet Sets/1300-1400.txt
# Text file saved to Spanish/Vocabulary/Quizlet Sets/1100-1200.txt
# Text file saved to Spanish/Vocabulary/Quizlet Sets/1200-1300.txt
# Text file saved to Spanish/Vocabulary/Quizlet Sets/200-300.txt
# Text file saved to Spanish/Vocabulary/Quizlet Sets/500-600.txt
# Text file saved to Spanish/Vocabulary/Quizlet Sets/0-100.txt
# Text file saved to Spanish/Vocabulary/Quizlet Sets/2250-2500.txt
# Text file saved to Spanish/Vocabulary/Quizlet Sets/1600-1700.txt
# Text file saved to Spanish/Vocabulary/Quizlet Sets/300-400.txt
# Text file saved to Spanish/Vocabulary/Quizlet Sets/1700-1800.txt
# Text file saved to Spanish/Vocabulary/Quizlet Sets/1500-1600.txt
# Text file saved to Spanish/Vocabulary/Quizlet Sets/1900-2000.txt
# Text file saved to Spanish/Vocabulary/Quizlet Sets/100-200.txt
# Text file saved to Spanish/Vocabulary/Quizlet Sets/800-900.txt
# Text file saved to Spanish/Vocabulary/Reverse Quizlet Sets/2750-3000.txt
# Text file saved to Spanish/Vocabulary/Reverse Quizlet Sets/2000-2250.txt
# Text file saved to Spanish/Vocabulary/Reverse Quizlet Sets/2500-2750.txt
# Text file saved to Spanish/Vocabulary/Reverse Quizlet Sets/1400-1500.txt
# Text file saved to Spanish/Vocabulary/Reverse Quizlet Sets/900-1000.txt
# Text file saved to Spanish/Vocabulary/Reverse Quizlet Sets/1800-1900.txt
# Text file saved to Spanish/Vocabulary/Reverse Quizlet Sets/600-700.txt
# Text file saved to Spanish/Vocabulary/Reverse Quizlet Sets/1000-1100.txt
# Text file saved to Spanish/Vocabulary/Reverse Quizlet Sets/700-800.txt
# Text file saved to Spanish/Vocabulary/Reverse Quizlet Sets/400-500.txt
# Text file saved to Spanish/Vocabulary/Reverse Quizlet Sets/1300-1400.txt
# Text file saved to Spanish/Vocabulary/Reverse Quizlet Sets/1100-1200.txt
# Text file saved to Spanish/Vocabulary/Reverse Quizlet Sets/1200-1300.txt
# Text file saved to Spanish/Vocabulary/Reverse Quizlet Sets/200-300.txt
# Text file saved to Spanish/Vocabulary/Reverse Quizlet Sets/500-600.txt
# Text file saved to Spanish/Vocabulary/Reverse Quizlet Sets/0-100.txt
# Text file saved to Spanish/Vocabulary/Reverse Quizlet Sets/2250-2500.txt
# Text file saved to Spanish/Vocabulary/Reverse Quizlet Sets/1600-1700.txt
# Text file saved to Spanish/Vocabulary/Reverse Quizlet Sets/300-400.txt
# Text file saved to Spanish/Vocabulary/Reverse Quizlet Sets/1700-1800.txt
# Text file saved to Spanish/Vocabulary/Reverse Quizlet Sets/1500-1600.txt
# Text file saved to Spanish/Vocabulary/Reverse Quizlet Sets/1900-2000.txt
# Text file saved to Spanish/Vocabulary/Reverse Quizlet Sets/100-200.txt
# Text file saved to Spanish/Vocabulary/Reverse Quizlet Sets/800-900.txt

# %%
# def makequizlet_step2(input_file):
#     output_file = input_file 
#     with open(input_file, 'r', newline='', encoding='utf-8') as infile:
#         reader = csv.reader(infile)
#         rows = list(reader)
# 
#     # Write the output CSV file with extra newlines
#     with open(output_file, 'w', newline='', encoding='utf-8') as outfile:
#         writer = csv.writer(outfile, quoting=csv.QUOTE_MINIMAL)
#         for row in rows:
#             writer.writerow(row)
#             writer.writerow([])  # Add a blank row
#             writer.writerow([])  # Add a blank row
#             writer.writerow([])
# 
#     print(f"Modified CSV file saved as {output_file}")
#     
# for file in os.listdir(os.path.join(language, 'Vocabulary/Quizlet Sets')):
#     if file[0] != '.':
#         print(file)
#         makequizlet_step2(os.path.join(language, 'Vocabulary/Quizlet Sets/' + file))

# %%
# import csv
# def make_quizlet_set(set_name):
#     df = pd.read_csv(os.path.join(language, 'Vocabulary', 'ChatGPT_Sets', set_name))
#     transdf = pd.read_csv(os.path.join(language, 'Vocabulary', 'Translated Sets', set_name))
#     
#     df['ChatGPT_Sentence'] = df['ChatGPT_Sentence'].apply(lambda x: re.sub(r'\n+', '\n', x))
#     
#     # Removing text within parentheses that start with 'see'
#     df['ChatGPT_Sentence'] = df['ChatGPT_Sentence'].str.replace(r'\(see[^)]*\)', '', regex=True)   
#     # Removing any extra spaces that might result from the replacement
#     df['ChatGPT_Sentence'] = df['ChatGPT_Sentence'].str.strip()
#     df['quizlet'] = transdf['POS'] + ' : ' + '*' + transdf['Translation'] + '*' + '\n\n' + df['ChatGPT_Sentence']
# 
# 
#     df = df[[language, 'quizlet']]
#     os.makedirs(os.path.join(language, 'Vocabulary', 'Quizlet Sets'), exist_ok = True)
#     output_path = os.path.join(language, 'Vocabulary', 'Quizlet Sets', set_name)
#     df.to_csv(output_path, index=False, quoting=csv.QUOTE_MINIMAL)
#     # df.to_csv(output_path, index=False, quoting=csv.QUOTE_NONE, escapechar = ddd)
#     print(f"CSV file saved to {output_path}")
#     return df

# %%
# def remove_quotes_from_csv(file_path):
#     # Read the CSV file and remove quotes
#     with open(file_path, 'r', newline='') as infile:
#         reader = csv.reader(infile)
#         rows = [[cell.replace('"', '') for cell in row] for row in reader]
#     
#     # Write the cleaned data back to the CSV file
#     with open(file_path, 'w', newline='') as outfile:
#         writer = csv.writer(outfile)
#         writer.writerows(rows)

# %%
# for file in os.listdir('Russian/Vocabulary/Quizlet Sets'):
#     if file[0] != '.':
#         print(file)
#         makequizlet_step2('Russian/Vocabulary/Quizlet Sets/' + file)
